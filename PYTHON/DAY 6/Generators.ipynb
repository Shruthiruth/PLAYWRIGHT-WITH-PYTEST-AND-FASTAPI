# %%
def create_cubes(n):
    result=[]
    for x in range(n):
        result.append(x**3)
    return result

# %%
for x in create_cubes(10):
    print(x)
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729

# %%
create_cubes(5)
# Out:
# [0, 1, 8, 27, 64]

# %%
def create_cubes(n):
 
    for x in range(n):
        yield x**3

# %%
list[create_cubes(6)]
# Out:
# list[<generator object create_cubes at 0x000002122FF56A80>]
